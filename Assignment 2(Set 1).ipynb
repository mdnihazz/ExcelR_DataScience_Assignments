# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Book1.csv')

# %%
df
# Out:
#      Name of company Measure X  Unnamed: 2  Unnamed: 3
# 0      Allied Signal    24.23%         NaN         NaN
# 1      Bankers Trust    25.53%         NaN         NaN
# 2      General Mills    25.41%         NaN         NaN
# 3     ITT Industries    24.14%         NaN         NaN
# 4   J.P.Morgan & Co.    29.62%         NaN         NaN
# 5    Lehman Brothers    28.25%         NaN         NaN
# 6           Marriott    25.81%         NaN         NaN
# 7                MCI    24.39%         NaN         NaN
# 8      Merrill Lynch    40.26%         NaN         NaN
# 9          Microsoft    32.95%         NaN         NaN
# 10    Morgan Stanley    91.36%         NaN         NaN
# 11  Sun Microsystems    25.99%         NaN         NaN
# 12         Travelers    39.42%         NaN         NaN
# 13        US Airways    26.71%         NaN         NaN
# 14    Warner-Lambert    35.00%         NaN         NaN

# %%
df.dtypes
# Out:
# Name of company     object
# Measure X           object
# Unnamed: 2         float64
# Unnamed: 3         float64
# dtype: object

# %%
df['Measure X'] = pd.to_numeric(df['Measure X'].replace('[^0-9\.-]','',regex = True))

# %%
df.dtypes
# Out:
# Name of company     object
# Measure X          float64
# Unnamed: 2         float64
# Unnamed: 3         float64
# dtype: object

# %%
df
# Out:
#      Name of company  Measure X  Unnamed: 2  Unnamed: 3
# 0      Allied Signal      24.23         NaN         NaN
# 1      Bankers Trust      25.53         NaN         NaN
# 2      General Mills      25.41         NaN         NaN
# 3     ITT Industries      24.14         NaN         NaN
# 4   J.P.Morgan & Co.      29.62         NaN         NaN
# 5    Lehman Brothers      28.25         NaN         NaN
# 6           Marriott      25.81         NaN         NaN
# 7                MCI      24.39         NaN         NaN
# 8      Merrill Lynch      40.26         NaN         NaN
# 9          Microsoft      32.95         NaN         NaN
# 10    Morgan Stanley      91.36         NaN         NaN
# 11  Sun Microsystems      25.99         NaN         NaN
# 12         Travelers      39.42         NaN         NaN
# 13        US Airways      26.71         NaN         NaN
# 14    Warner-Lambert      35.00         NaN         NaN

# %%
df['Measure X'].describe()
# Out:
# count    15.000000
# mean     33.271333
# std      16.945401
# min      24.140000
# 25%      25.470000
# 50%      26.710000
# 75%      33.975000
# max      91.360000
# Name: Measure X, dtype: float64

# %%
df['Measure X'].var()
# Out:
# 287.1466123809524

# %%
plt.boxplot(df['Measure X'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x24580ce6a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x24580cf1070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x24580ce67c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x24580cf1610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x24580cf18e0>],
#  'means': []}

# %%
plt.figure(figsize = (8,8))
plt.pie(df['Measure X'], labels=df['Name of company'], autopct= '%.2f%%')
plt.title('Name of Companies with respect to X', fontsize = 18, fontweight = 'bold', color='r')
plt.savefig('Question1piechart.png')
plt.show()
